# %% [markdown]
# ## Plotting DEGs for Longitudinal converters

# %%
# load libraries
quiet_library <- function(...) {
    suppressPackageStartupMessages(library(...))
}
quiet_library(tidyverse)
quiet_library(Seurat)
quiet_library(ggplot2)
quiet_library(Matrix)
quiet_library(dplyr)
quiet_library(viridis)
quiet_library(harmony)
quiet_library(future)
quiet_library(future.apply)
quiet_library(SingleCellExperiment)
quiet_library(SeuratDisk)
quiet_library(ggpubr)
quiet_library(knitr)
quiet_library(plotly)
quiet_library(ggsci)
quiet_library(aplot)
quiet_library(cowplot)
options(warn = -1)

# %%
# Check number of cores
future::availableCores()
# Set up parallel processing to run when using 'future' functions 
future::plan(strategy = "multicore", workers = future::availableCores()-5)  
options(future.globals.maxSize = 1000 * 1024^3)
# to turn off parallel processing run line below
# future::plan(strategy = "sequential")
# Out:
# system
#     64

# %%
# define the color palette to be used
npg_color <- c("#E64B35FF", "#4DBBD5FF", "#00A087FF", "#3C5488FF", "#F39B7FFF", 
               "#8491B4FF", "#91D1C2FF", "#DC0000FF", "#7E6148FF", "#B09C85FF")
nejm_color <- c("#BC3C29FF", "#0072B5FF", "#E18727FF", "#20854EFF", "#7876B1FF", "#6F99ADFF", "#FFDC91FF", "#EE4C97FF")
jama_color <- c("#374E55FF", "#DF8F44FF", "#00A1D5FF", "#B24745FF", "#79AF97FF", "#6A6599FF", "#80796BFF")
jco_color <- c("#0073C2FF", "#EFC000FF", "#868686FF", "#CD534CFF", "#7AA6DCFF", "#003C67FF", "#8F7700FF")
cluster_colors <- c("#DC050C", "#FB8072", "#1965B0", "#7BAFDE", "#882E72", "#B17BA6", "#FF7F00", "#FDB462", "#E7298A", 
    "#E78AC3", "#33A02C", "#B2DF8A", "#55A1B1", "#8DD3C7", "#A6761D", "#E6AB02", "#7570B3", "#BEAED4", "#666666", "#999999", 
    "#aa8282", "#d4b7b7", "#8600bf", "#ba5ce3", "#808000", "#aeae5c", "#1e90ff", "#00bfff", "#56ff0d", "#ffff00")

cluster_colors_ext <- colorRampPalette(cluster_colors)(75)
options(repr.plot.width = 20, repr.plot.height = 15)

# %%
# reading the IH celltype color coding file 
IH_colors_df=read.csv("/home/jupyter/ALTRA_ANALYSIS/Deep_clean/Figure_notebooks/files/input_files/Color_Annotation_and_Order_FINAL 1.csv")
IH_colors_df%>%head(3)
IH_colors_df%>%dim
# Out:
#   xpos label                  color
# 1 1    SOX4+ naive CD4 T cell #2B5777
# 2 2    Core naive CD4 T cell  #597FC6
# 3 3    ISG+ naive CD4 T cell  #072E77
# [1] 71  3

# %%
#loading aim 3 deg results file
degs_a3=read.csv("/home/jupyter/ALTRA_ANALYSIS/Deep_clean/Figure_notebooks/files/input_files/certpro_Zi_files/ALTRA_AIM3_certpro_scRNA_Pseudobulk_AIFI_l3_mixed_models_time_result_750days.csv")
degs_a3%>%head(3)
# Out:
#   celltype         effect group term               estimate      std.error
# 1 Adaptive NK cell fixed  NA    days_to_conversion -4.601178e-04 0.0001726325
# 2 Adaptive NK cell fixed  NA    days_to_conversion  2.698218e-04 0.0001816877
# 3 Adaptive NK cell fixed  NA    days_to_conversion -1.742457e-05 0.0001246150
#   statistic  df       p.value    gene     q_values  sig
# 1 -2.6653027 43.00000 0.01079008 AAK1     0.3471929 ns
# 2  1.4850857 43.00000 0.14481591 AASDHPPT 0.5004335 ns
# 3 -0.1398272 42.98683 0.88944965 AATF     0.7853112 ns

# %%
degs_a3%>%group_by(celltype)%>%summarise(counts=n())
# Out:
#    celltype                             counts
# 1  Adaptive NK cell                     3528
# 2  Adaptive NK cell_uk1_T               2008
# 3  C1Q+ CD16 monocyte                   4238
# 4  CD14+ cDC2                           6757
# 5  CD27+ effector B cell                4302
# 6  CD27- effector B cell                2354
# 7  CD4 MAIT                             2183
# 8  CD56bright NK cell                   5093
# 9  CD8 MAIT                             6163
# 10 CD8aa                                1348
# 11 CD95 memory B cell                   2352
# 12 CM CD4 T cell                        5497
# 13 CM CD4 T cell_uk1_CD8                3896
# 14 CM CD4 T cell_uk2                     396
# 15 CM CD8 T cell                        5844
# 16 CMP cell                             3034
# 17 Core CD14 monocyte                   7116
# 18 Core CD16 monocyte                   7644
# 19 Core memory B cell                   6110
# 20 Core naive B cell                    4791
# 21 Core naive CD4 T cell                4950
# 22 Core naive CD8 T cell                5622
# 23 DN T cell                            2323
# 24 Early memory B cell                   997
# 25 Erythrocyte                          1127
# 26 GZMB+ Vd2 gdT                        5336
# 27 GZMB- CD27+ EM CD4 T cell            5645
# 28 GZMB- CD27+ EM CD4 T cell_uk1_CD8    1856
# 29 GZMB- CD27- EM CD4 T cell            6061
# 30 GZMB- CD27- EM CD4 T cell_uk1_CD8    1894
# ⋮  ⋮                                    ⋮
# 41 ISG+ CD16 monocyte                   4456
# 42 ISG+ CD56dim NK cell                 1799
# 43 ISG+ cDC2                            3498
# 44 ISG+ memory CD4 T cell               2579
# 45 ISG+ memory CD8 T cell                870
# 46 ISG+ naive B cell                    1811
# 47 ISG+ naive CD4 T cell                2154
# 48 ISG+ naive CD8 T cell                 787
# 49 Intermediate monocyte                5747
# 50 KLRB1+ memory CD4 Treg               1904
# 51 KLRF1+ GZMB+ CD27- EM CD8 T cell     6950
# 52 KLRF1+ effector Vd1 gdT              2303
# 53 KLRF1+GZMB+_CD27-_EM_CD8_uk3         2481
# 54 KLRF1- GZMB+ CD27- EM CD8 T cell     5810
# 55 KLRF1- GZMB+ CD27- memory CD4 T cell 6032
# 56 KLRF1- effector Vd1 gdT              3039
# 57 Memory CD4 Treg                      5762
# 58 Naive CD4 Treg                       5353
# 59 Naive Vd1 gdT                        3166
# 60 Plasma cell                          3275
# 61 Platelet                              862
# 62 Proliferating NK cell                2930
# 63 Proliferating T cell                 3916
# 64 SOX4+ Vd1 gdT                         988
# 65 SOX4+ naive CD4 T cell               2932
# 66 SOX4+ naive CD8 T cell               1416
# 67 Transitional B cell                  5832
# 68 Type 2 polarized memory B cell       1673
# 69 cDC1                                 4130
# 70 pDC                                  5546

# %%
##adding the direction column

degs_a3=degs_a3%>%
    filter(!is.na(p.value) & !is.na(estimate)) %>% mutate(direction=if_else(estimate>0, 'positive', 'negative'))
degs_a3 %>% head()
# Out:
#   celltype         effect group term               estimate      std.error
# 1 Adaptive NK cell fixed  NA    days_to_conversion -4.601178e-04 0.0001726325
# 2 Adaptive NK cell fixed  NA    days_to_conversion  2.698218e-04 0.0001816877
# 3 Adaptive NK cell fixed  NA    days_to_conversion -1.742457e-05 0.0001246150
# 4 Adaptive NK cell fixed  NA    days_to_conversion -1.164469e-04 0.0001820954
# 5 Adaptive NK cell fixed  NA    days_to_conversion -2.050641e-04 0.0002058161
# 6 Adaptive NK cell fixed  NA    days_to_conversion -3.740837e-06 0.0001426124
#   statistic  df       p.value    gene     q_values  sig direction
# 1 -2.6653027 43.00000 0.01079008 AAK1     0.3471929 ns  negative
# 2  1.4850857 43.00000 0.14481591 AASDHPPT 0.5004335 ns  positive
# 3 -0.1398272 42.98683 0.88944965 AATF     0.7853112 ns  negative
# 4 -0.6394831 41.24902 0.52604448 ABCB1    0.7095864 ns  negative
# 5 -0.9963461 43.00000 0.32465598 ABCE1    0.6228828 ns  negative
# 6 -0.0262308 43.00000 0.97919461 ABCF1    0.7952158 ns  negative

# %%
# plot degs counts
# calculate the deg counts per cell types
deg_counts_a3 <- degs_a3 %>% 
    dplyr::filter(q_values<0.1) %>% 
    group_by(celltype, direction) %>% summarise(deg_counts_a3=n()) %>%
    mutate(deg_counts_a3=if_else(direction=='positive', deg_counts_a3, -deg_counts_a3),
          enriched=if_else(direction=='positive', 'increase with time to conversion','Decrease'))
deg_counts_a3 %>%head(4)
# Out:
# `summarise()` has grouped output by 'celltype'. You can override using the
# `.groups` argument.
#   celltype              direction deg_counts_a3
# 1 CD27+ effector B cell negative     -1
# 2 CD27+ effector B cell positive      3
# 3 CM CD4 T cell         negative  -1418
# 4 CM CD4 T cell         positive   1294
#   enriched
# 1 Decrease
# 2 increase with time to conversion
# 3 Decrease
# 4 increase with time to conversion

# %%
# ordering the celltypes based on IH order for plotting 
deg_counts_a3 <- deg_counts_a3 %>% rename(count = deg_counts_a3)
deg_counts_a3 <- deg_counts_a3 %>% rename(Expression = direction)

# %%
orders3<-deg_counts_a3
orders3$count<-abs(orders3$count)
orders3<-orders3%>%
  group_by(celltype) %>%
  summarize(value = sum(count))%>%arrange(desc(value)) %>% select (celltype) %>% pull()
 
# Load predetermined list from CSV file
predetermined_list <- read.csv("/home/jupyter/ALTRA_ANALYSIS/Deep_clean/Immune_Cell_Order_forDEGsummary - Sheet1.csv")
 
 
#Label CD8aa T cell in pre-determined list at CD8aa
predetermined_list$FINAL.ORDER <- gsub("CD8aa T cell", "CD8aa", predetermined_list$FINAL.ORDER)
predetermined_list$FINAL.ORDER <- gsub("Core naive CD8 T cell ", "Core naive CD8 T cell", predetermined_list$FINAL.ORDER)
 
# Create a vector of unique values of FINAL.ORDER
order_values <- unique(predetermined_list$FINAL.ORDER)
 
# Create a vector of unique values of Expression
expression_values <- unique(deg_counts_a3$Expression)
 
# Generate all unique combinations of FINAL.ORDER and Expression
combinations <- expand.grid(FINAL.ORDER = order_values,
                             Expression = expression_values)
 
# Ordering the combinations by FINAL.ORDER when grouped with Expression
ordered_combinations <- combinations[order(combinations$FINAL.ORDER, combinations$Expression), ]
 
ordered_combinations <- ordered_combinations %>% rename(celltype = FINAL.ORDER)
 
# Merge the dataframes based on "celltype" and "Expression"
merged_df<- merge(ordered_combinations, deg_counts_a3, by = c("celltype", "Expression"), all.x = TRUE)
 
merged_df$count <- ifelse(is.na(merged_df$count), 0, merged_df$count)

# %%
merged_df%>%head(3)
# Out:
#   celltype               Expression count enriched
# 1 SOX4+ naive CD4 T cell negative       0 NA
# 2 SOX4+ naive CD4 T cell positive       0 NA
# 3 Core naive CD4 T cell  negative   -1368 Decrease

# %%
# making IH_colors as a vector for giving colors to the plot 
IH_colors <- setNames(IH_colors_df$color,IH_colors_df$label)
IH_colors
# Out:
#               SOX4+ naive CD4 T cell                Core naive CD4 T cell
#                            "#2B5777"                            "#597FC6"
#                ISG+ naive CD4 T cell                        CM CD4 T cell
#                            "#072E77"                            "#6793A4"
#            GZMB- CD27+ EM CD4 T cell            GZMB- CD27- EM CD4 T cell
#                            "#406B9C"                            "#233C5B"
#               ISG+ memory CD4 T cell KLRF1- GZMB+ CD27- memory CD4 T cell
#                            "#5480A3"                            "#628088"
#                       Naive CD4 Treg                      Memory CD4 Treg
#                            "#8EB5D7"                            "#001A9A"
#               KLRB1+ memory CD4 Treg                GZMK+ memory CD4 Treg
#                            "#3B76C1"                            "#A3B7C2"
#                      Memory CD8 Treg               KLRB1+ memory CD8 Treg
#                            "#C3D1DA"                            "#C7E0C6"
#                            DN T cell                 Proliferating T cell
#                            "#656E68"                            "#AEAEB0"
#               SOX4+ naive CD8 T cell                Core naive CD8 T cell
#                            "#465F32"                            "#63A686"
#                ISG+ naive CD8 T cell                        CM CD8 T cell
#                            "#869A94"                            "#6D9F5E"
#            GZMK+ CD27+ EM CD8 T cell     KLRF1- GZMB+ CD27- EM CD8 T cell
#                            "#95BDA1"                            "#59895F"
#            GZMK- CD27+ EM CD8 T cell     KLRF1+ GZMB+ CD27- EM CD8 T cell
#                            "#314937"                            "#4E695B"
#               ISG+ memory CD8 T cell                                CD8aa
#                            "#94C0AD"                            "#7ECDAD"
#                        SOX4+ Vd1 gdT                        Naive Vd1 gdT
#                            "#B6D7C8"                            "#537E41"
#              KLRF1- effector Vd1 gdT              KLRF1+ effector Vd1 gdT
#                            "#A39E78"                            "#7CB38E"
#                        GZMK+ Vd2 gdT                        GZMB+ Vd2 gdT
#                            "#72AF5A"                            "#AECFB1"
#                             CD8 MAIT                             CD4 MAIT
#                            "#1E8F64"                            "#6F723F"
#                            ISG+ MAIT                  Transitional B cell
#                            "#BBB788"                            "#9C6469"
#                    Core naive B cell                    ISG+ naive B cell
#                            "#D5ABAB"                            "#D9A996"
#                  Early memory B cell                   Core memory B cell
#                            "#362027"                            "#B16B72"
#              Activated memory B cell       Type 2 polarized memory B cell
#                            "#60545A"                            "#4E2927"
#                   CD95 memory B cell                CD27+ effector B cell
#                            "#EBC3A7"                            "#F4CEC3"
#                CD27- effector B cell                          Plasma cell
#                            "#A3787B"                            "#784D47"
#                   CD56bright NK cell                GZMK+ CD56dim NK cell
#                            "#FF7F55"                            "#A31001"
#                GZMK- CD56dim NK cell                     Adaptive NK cell
#                            "#E16040"                            "#781B15"
#                 ISG+ CD56dim NK cell                Proliferating NK cell
#                            "#EEA172"                            "#CC3B18"
#                   Core CD14 monocyte                   ISG+ CD14 monocyte
#                            "#F6831B"                            "#DE5A07"
#                  IL1B+ CD14 monocyte                Intermediate monocyte
#                            "#BE4C26"                            "#B75228"
#                   Core CD16 monocyte                   ISG+ CD16 monocyte
#                            "#FCAF87"                            "#DB6A2E"
#                   C1Q+ CD16 monocyte                           CD14+ cDC2
#                            "#F4BA81"                            "#FEDC7A"
#                        HLA-DRhi cDC2                            ISG+ cDC2
#                            "#BE6E23"                            "#8C6527"
#                                 cDC1                                  pDC
#                            "#F8C755"                            "#FBB64E"
#                                 ASDC                                  ILC
#                            "#8A4E1C"                            "#F4AD3A"
#                             CLP cell                             CMP cell
#                            "#FCDB97"                            "#5B3006"
#                         BaEoMaP cell                             Platelet
#                            "#3D1F15"                            "#5B3930"
#                          Erythrocyte
#                            "#1F1515"

# %%
options(repr.plot.width = 25, repr.plot.height = 11)

p1 <- ggplot(merged_df, aes(x = celltype, y = count, fill = celltype)) +
  geom_bar(stat = "identity", width = 0.8, aes(alpha = Expression)) + 
  scale_fill_manual(values = IH_colors) +
  labs(y = "DEG Counts", x = "Cell Type") +
  scale_alpha_manual(values = c(0.5, 1)) +
  theme_bw(base_size = 8.5) +
  # facet_grid(contrast ~ .) +  # Uncomment this line if you want to use facet_grid
  theme(legend.position = "none",
        axis.text.x = element_text(size = 20,angle = 90, vjust = 0.5, hjust = 1, color = IH_colors),
        axis.text.y = element_text(size = 20, face = "bold"),
        axis.title.y = element_text(size = 20, face = "bold"),
        axis.title.x = element_text(size = 20, face = "bold"))

p1
# Out:
# plot without title

# %%
# Saving the figure
ggsave("/home/jupyter//ALTRA_ANALYSIS/Deep_clean/Figure_files/Certpro_figures/Plots_for_manuscript/Fig_2D deg_bar_plot_q<0_1.pdf", p1, width = 25, height = 11)

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/jupyter/libs/r_scrna/lib/libopenblasp-r0.3.24.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] cowplot_1.1.3               aplot_0.2.3
#  [3] ggsci_3.2.0                 plotly_4.10.4
#  [5] knitr_1.47                  ggpubr_0.6.0
#  [7] SeuratDisk_0.0.0.9021       SingleCellExperiment_1.22.0
#  [9] SummarizedExperiment_1.30.2 Biobase_2.60.0
# [11] GenomicRanges_1.52.1        GenomeInfoDb_1.36.4
# [13] IRanges_2.34.1              S4Vectors_0.38.2
# [15] BiocGenerics_0.46.0         MatrixGenerics_1.12.3
# [17] matrixStats_1.3.0           future.apply_1.11.2
# [19] future_1.33.2               harmony_1.2.0
# [21] Rcpp_1.0.12                 viridis_0.6.5
# [23] viridisLite_0.4.2           Matrix_1.6-1.1
# [25] SeuratObject_5.0.0          Seurat_4.4.0
# [27] lubridate_1.9.3             forcats_1.0.0
# [29] stringr_1.5.1               dplyr_1.1.4
# [31] purrr_1.0.2                 readr_2.1.5
# [33] tidyr_1.3.1                 tibble_3.2.1
# [35] ggplot2_3.5.1               tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22        splines_4.3.1           later_1.3.2
#   [4] pbdZMQ_0.3-11           bitops_1.0-7            ggplotify_0.1.2
#   [7] polyclip_1.10-6         lifecycle_1.0.4         rstatix_0.7.2
#  [10] globals_0.16.3          lattice_0.22-6          hdf5r_1.3.10
#  [13] MASS_7.3-60             backports_1.5.0         magrittr_2.0.3
#  [16] httpuv_1.6.15           sctransform_0.4.1       spam_2.10-0
#  [19] sp_2.1-4                spatstat.sparse_3.1-0   reticulate_1.38.0
#  [22] pbapply_1.7-2           RColorBrewer_1.1-3      abind_1.4-5
#  [25] zlibbioc_1.46.0         Rtsne_0.17              RCurl_1.98-1.14
#  [28] yulab.utils_0.1.4       GenomeInfoDbData_1.2.10 ggrepel_0.9.5
#  [31] irlba_2.3.5.1           listenv_0.9.1           spatstat.utils_3.0-5
#  [34] goftest_1.2-3           spatstat.random_3.2-3   fitdistrplus_1.1-11
#  [37] parallelly_1.37.1       leiden_0.4.3.1          codetools_0.2-20
#  [40] DelayedArray_0.26.7     tidyselect_1.2.1        farver_2.1.2
#  [43] base64enc_0.1-3         spatstat.explore_3.2-7  jsonlite_1.8.8
#  [46] progressr_0.14.0        ggridges_0.5.6          survival_3.7-0
#  [49] systemfonts_1.1.0       tools_4.3.1             ragg_1.2.5
#  [52] ica_1.0-3               glue_1.7.0              gridExtra_2.3
#  [55] xfun_0.45               IRdisplay_1.1           withr_3.0.0
#  [58] fastmap_1.2.0           fansi_1.0.6             digest_0.6.36
#  [61] timechange_0.3.0        R6_2.5.1                mime_0.12
#  [64] gridGraphics_0.5-1      textshaping_0.4.0       colorspace_2.1-0
#  [67] Cairo_1.6-2             scattermore_1.2         tensor_1.5
#  [70] spatstat.data_3.1-2     utf8_1.2.4              generics_0.1.3
#  [73] data.table_1.15.4       httr_1.4.7              htmlwidgets_1.6.4
#  [76] S4Arrays_1.0.6          uwot_0.2.2              pkgconfig_2.0.3
#  [79] gtable_0.3.5            lmtest_0.9-40           XVector_0.40.0
#  [82] htmltools_0.5.8.1       carData_3.0-5           dotCall64_1.1-1
#  [85] scales_1.3.0            png_0.1-8               ggfun_0.1.5
#  [88] tzdb_0.4.0              reshape2_1.4.4          uuid_1.2-0
#  [91] nlme_3.1-165            cachem_1.1.0            repr_1.1.7
#  [94] zoo_1.8-12              KernSmooth_2.23-24      parallel_4.3.1
#  [97] miniUI_0.1.1.1          pillar_1.9.0            grid_4.3.1
# [100] vctrs_0.6.5             RANN_2.6.1              promises_1.3.0
# [103] car_3.1-2               xtable_1.8-4            cluster_2.1.6
# [106] evaluate_0.24.0         cli_3.6.3               compiler_4.3.1
# [109] rlang_1.1.4             crayon_1.5.3            ggsignif_0.6.4
# [112] labeling_0.4.3          fs_1.6.4                plyr_1.8.9
# [115] stringi_1.8.4           deldir_2.0-4            munsell_0.5.1
# [118] lazyeval_0.2.2          spatstat.geom_3.2-9     IRkernel_1.3.2
# [121] hms_1.1.3               patchwork_1.2.0         bit64_4.0.5
# [124] shiny_1.8.1.1           ROCR_1.0-11             memoise_2.0.1
# [127] igraph_2.0.3            broom_1.0.6             bit_4.0.5
