# %% [markdown]
# ## Frequency plots for Non-naive CD4 T cells

# %%
# load libraries
quiet_library <- function(...) {
    suppressPackageStartupMessages(library(...))
}
quiet_library(tidyverse)
quiet_library(Seurat)
quiet_library(ggplot2)
quiet_library(Matrix)
quiet_library(dplyr)
quiet_library(viridis)
#quiet_library(harmony)
quiet_library(future)
quiet_library(future.apply)
quiet_library(SingleCellExperiment)
#quiet_library(SeuratDisk)
quiet_library(knitr)
quiet_library(plotly)
quiet_library(lme4)
#quiet_library(ggpubr)
quiet_library(ggrepel)
quiet_library(ggthemes)
quiet_library(GSVA)
quiet_library(tidyr)
quiet_library(SummarizedExperiment)
quiet_library(cowplot)

# %%
# Check number of cores
future::availableCores()
# Set up parallel processing to run when using 'future' functions 
future::plan(strategy = "multicore", workers = future::availableCores()-5)  
options(future.globals.maxSize = 1000 * 1024^3)
# to turn off parallel processing run line below
# future::plan(strategy = "sequential")
# Out:
# system
#     64

# %%
# define the color palette to be used
npg_color <- c("#E64B35FF", "#4DBBD5FF", "#00A087FF", "#3C5488FF", "#F39B7FFF", 
               "#8491B4FF", "#91D1C2FF", "#DC0000FF", "#7E6148FF", "#B09C85FF")
nejm_color <- c("#BC3C29FF", "#0072B5FF", "#E18727FF", "#20854EFF", "#7876B1FF", "#6F99ADFF", "#FFDC91FF", "#EE4C97FF")
jama_color <- c("#374E55FF", "#DF8F44FF", "#00A1D5FF", "#B24745FF", "#79AF97FF", "#6A6599FF", "#80796BFF")
jco_color <- c("#0073C2FF", "#EFC000FF", "#868686FF", "#CD534CFF", "#7AA6DCFF", "#003C67FF", "#8F7700FF")
cluster_colors <- c("#DC050C", "#FB8072", "#1965B0", "#7BAFDE", "#882E72", "#B17BA6", "#FF7F00", "#FDB462", "#E7298A", 
    "#E78AC3", "#33A02C", "#B2DF8A", "#55A1B1", "#8DD3C7", "#A6761D", "#E6AB02", "#7570B3", "#BEAED4", "#666666", "#999999", 
    "#aa8282", "#d4b7b7", "#8600bf", "#ba5ce3", "#808000", "#aeae5c", "#1e90ff", "#00bfff", "#56ff0d", "#ffff00")
coolors_clrs<-c("#EFB0A1","#009FF5","#1A5E9B","#42E2B8","#4ECDC4","#89B6A5","#F1D26A","#D5B0AC","#EDABB1","#02504D","#AA9674","#E64B35FF","#4DBBD5FF","#00A087FF")

cluster_colors_ext <- colorRampPalette(cluster_colors)(36)
options(repr.plot.width =5, repr.plot.height =5)

# %%
fig_path="/home/workspace/ALTRA_DC/ALTRA_ANALYSIS/Deep_clean/Review_1/output_figs"

# %%
#' # Example usage of PlotFreqLinePlot function
#' # This function plots frequency line plots with model predictions.
#' PlotFreqLinePlot1(frequency_table, model_fit, palette, fig_path = "path/to/save", fig_name = "fig_name",
#'                  x_var = "days_to_conversion", y_var = "clr", color_var = "subject.subjectGuid",
#'                  shape_var = "sex", title = "Cluster 9", x_label = "Days to Conversion", 
#'                  y_label = "CLR", annotation_text = "p=0.055", annotation_x = -600, 
#'                  annotation_y = 1, annotation_color = "red")
#'
#' @export
#' @param frequency_table The input data frame containing frequency values to plot.
#' @param model_fit A fitted model object for predictions.
#' @param palette A color palette for the plot.
#' @param fig_path The file path where the plot will be saved (optional).
#' @param fig_name The name of the file where the plot will be saved (optional).
#' @param x_var The variable for the x-axis (default is "days_to_conversion").
#' @param y_var The variable for the y-axis (default is "clr").
#' @param color_var The variable to determine line colors (default is "subject.subjectGuid").
#' @param shape_var The variable to determine point shapes (default is "sex").
#' @param title The title of the plot.
#' @param x_label The x-axis label (default is "Days to Conversion").
#' @param y_label The y-axis label (default is "CLR").
#' @param annotation_text Text for annotation on the plot.
#' @param annotation_x X coordinate for the annotation.
#' @param annotation_y Y coordinate for the annotation.
#' @param annotation_color Color of the annotation text.
PlotFreqLinePlot1 <- function(frequency_table, model_fit, palette, fig_path = NULL, fig_name = NULL,
                             x_var = "days_to_conversion", y_var = "clr", color_var = "subject.subjectGuid",
                             shape_var = "sex", title = "Cluster 9", x_label = "Days to Conversion", 
                             y_label = "CLR", 
                              #annotation_text = "padj=", 
                              annotation_x = -600, 
                             annotation_y = 1, annotation_color = "red", x_limits = NULL, y_limits = NULL) {
    require(ggplot2)
    require(ggeffects)

    # Extract the prediction data frame
    pred.mm <- ggpredict(model_fit, terms = c(x_var))  # Adjusted to use x_var

    # plot
    p1 <- frequency_table %>%
        ggplot() +
        geom_line(aes(x = .data[[x_var]], y = .data[[y_var]], color = .data[[color_var]]), size = 1) + 
        geom_point(aes(x = .data[[x_var]], y = .data[[y_var]], shape = .data[[shape_var]])) + 
        geom_line(data = pred.mm, aes(x = x, y = predicted), color = "#8F7700FF", size = 2) +          
        geom_ribbon(data = pred.mm, aes(x = x, ymin = predicted - 3 * std.error, ymax = predicted + 3 * std.error), 
                    fill = "#8F7700FF", alpha = 0.3) + 
        #annotate(geom = "text", x = annotation_x, y = annotation_y, label = annotation_text, size = 6,
                # color = annotation_color) +
        labs(title = title) + 
        xlab(x_label) +  
        ylab(y_label) +
        scale_color_manual(values = palette) + 
        theme_few()+
        theme(
            text = element_text(size = 10, face = "bold"),  
            axis.title = element_text(size = 10, face = "bold"),  
            axis.text = element_text(size = 10, face = "bold"),  
            plot.title = element_text(size = 10, face = "bold"),  
            legend.position = "none",  # Remove all legends
            panel.grid.minor = element_blank(),
            panel.grid.major = element_blank(),
            panel.background = element_blank()
        ) +
        scale_shape_manual(values = c(1, 2))  # No need for guides() here

    # Adjust the scale of x and y axes if limits are provided
    if (!is.null(x_limits)) {
        p1 <- p1 + scale_x_continuous(limits = x_limits)
    }
    if (!is.null(y_limits)) {
        p1 <- p1 + scale_y_continuous(limits = y_limits)
    }

    # Code to save the plot if fig_path and fig_name are provided
    if (!missing(fig_path) && !missing(fig_name) && nzchar(fig_path) && nzchar(fig_name)) {
        # Construct the full file path with the figure name and desired file extension
        file_name <- paste0(fig_path, "/", fig_name)
        # Use ggsave to save the plot
        ggsave(file_name, plot = p1, width = 4, height = 4, dpi = 300)
    }
    return(p1)
}

# %%
## reading the frequency results
fq_clr=read.csv("/home/workspace/ALTRA_DC//ALTRA_ANALYSIS/Deep_clean/certpro/output_files/CD4T_mem_certpro_Frq_clr_res_0_4(c0-c18)_R.csv")
fq_clr%>%head(3)
# Out:
#   X sample.sampleKitGuid BMI      days_to_conversion ageAtDraw
# 1 1 KT00052              24.65716 -714               56
# 2 2 KT00052              24.65716 -714               56
# 3 3 KT00052              24.65716 -714               56
#   subject.biologicalSex subject.subjectGuid bmi_conv age_conv Status_Long
# 1 Female                CU1009              25.64892 58       pre
# 2 Female                CU1009              25.64892 58       pre
# 3 Female                CU1009              25.64892 58       pre
#   Status_Xsec Age2023 anti_ccp3 anti_ccp3_finalCombined anti_ccp31 clusters
# 1 at_risk     60      88        88                      74         cluster0
# 2 at_risk     60      88        88                      74         cluster1
# 3 at_risk     60      88        88                      74         cluster2
#   frequency_live clr
# 1 0.10423826     0.9848633
# 2 0.07073310     0.5970978
# 3 0.09621993     0.9048206

# %%
meta=read.csv("/home/workspace/ALTRA_DC//ALTRA_ANALYSIS/Deep_clean/AIM3/input_csv_files/2023-11-22_ALTRA_Metadata_labs.csv")

# %%
meta_filtered <- meta %>% 
  filter(subject.subjectGuid != "CU1015")
## becuase CU1015 is not used in longitudinal analysis

# %%
meta_a3=meta_filtered%>%filter(Status_Long %in% c("pre","conversion"))
meta_a3=select(meta_a3,c(Status_Long,sample.sampleKitGuid))
meta_a3%>%dim
meta_a3%>%head(2)
# Out:
# [1] 73  2
#   Status_Long sample.sampleKitGuid
# 1 pre         KT00052
# 2 pre         KT00056

# %%
A3_clr <- merge(meta_a3, fq_clr, by='sample.sampleKitGuid', all.x=TRUE)
A3_clr%>%dim
A3_clr%>%head
# Out:
# [1] 1243   19
#   sample.sampleKitGuid Status_Long.x X  BMI      days_to_conversion ageAtDraw
# 1 KT00052              pre            3 24.65716 -714               56
# 2 KT00052              pre            1 24.65716 -714               56
# 3 KT00052              pre            4 24.65716 -714               56
# 4 KT00052              pre           13 24.65716 -714               56
# 5 KT00052              pre            2 24.65716 -714               56
# 6 KT00052              pre           17 24.65716 -714               56
#   subject.biologicalSex subject.subjectGuid bmi_conv age_conv Status_Long.y
# 1 Female                CU1009              25.64892 58       pre
# 2 Female                CU1009              25.64892 58       pre
# 3 Female                CU1009              25.64892 58       pre
# 4 Female                CU1009              25.64892 58       pre
# 5 Female                CU1009              25.64892 58       pre
# 6 Female                CU1009              25.64892 58       pre
#   Status_Xsec Age2023 anti_ccp3 anti_ccp3_finalCombined anti_ccp31 clusters
# 1 at_risk     60      88        88                      74         cluster2
# 2 at_risk     60      88        88                      74         cluster0
# 3 at_risk     60      88        88                      74         cluster3
# 4 at_risk     60      88        88                      74         cluster12
# 5 at_risk     60      88        88                      74         cluster1
# 6 at_risk     60      88        88                      74         cluster16
#   frequency_live clr
# 1 0.09621993      0.9048206
# 2 0.10423826      0.9848633
# 3 0.06872852      0.5683484
# 4 0.04696449      0.1875759
# 5 0.07073310      0.5970978
# 6 0.02290951     -0.5302639

# %%
altra=read.csv("/home/workspace/ALTRA_DC//ALTRA_ANALYSIS/Deep_clean/Figure_notebooks/files/input_files/certpro_Zi_files/Figure_input_files/ALTRA_Fig1_Master_meta
                    .csv")
altra%>%head(3)
altra=select(altra,c("sample.sampleKitGuid","s1_ids","Status_new"))
altra%>%head(3)
# Out:
#   X Status_Xsec   Status_Long sample.sampleKitGuid sample.drawDate
# 1 1 ALTRA_healthy NA          KT02284              2022-10-01
# 2 2 ALTRA_healthy NA          KT02286              2022-08-01
# 3 3 ALTRA_healthy NA          KT02287              2022-05-01
#   sample.daysSinceFirstVisit subject.subjectGuid subject.biologicalSex
# 1 0                          SD1021              Female
# 2 0                          SD1022              Female
# 3 0                          SD1015              Female
#   subject.birthYear days_to_conversion number_of_days_to_from_ra_conversion_cu
# 1 1971              NA                 NA
# 2 1985              NA                 NA
# 3 1963              NA                 NA
#   anti_ccp3_finalCombined status        time  s1   s1_ids Status_new
# 1 0                       ALTRA_healthy -2000 CON1 CON101 CON1
# 2 2                       ALTRA_healthy -2000 CON1 CON102 CON1
# 3 0                       ALTRA_healthy -2000 CON1 CON103 CON1
#   sample.sampleKitGuid s1_ids Status_new
# 1 KT02284              CON101 CON1
# 2 KT02286              CON102 CON1
# 3 KT02287              CON103 CON1

# %%
A3_clr1 <- left_join(A3_clr, altra, by = "sample.sampleKitGuid",)
A3_clr1%>%head(3)
A3_clr1%>%dim
# Out:
#   sample.sampleKitGuid Status_Long.x X BMI      days_to_conversion ageAtDraw
# 1 KT00052              pre           3 24.65716 -714               56
# 2 KT00052              pre           1 24.65716 -714               56
# 3 KT00052              pre           4 24.65716 -714               56
#   subject.biologicalSex subject.subjectGuid bmi_conv age_conv ⋯ Status_Xsec
# 1 Female                CU1009              25.64892 58       ⋯ at_risk
# 2 Female                CU1009              25.64892 58       ⋯ at_risk
# 3 Female                CU1009              25.64892 58       ⋯ at_risk
#   Age2023 anti_ccp3 anti_ccp3_finalCombined anti_ccp31 clusters frequency_live
# 1 60      88        88                      74         cluster2 0.09621993
# 2 60      88        88                      74         cluster0 0.10423826
# 3 60      88        88                      74         cluster3 0.06872852
#   clr       s1_ids Status_new
# 1 0.9048206 ARI36  LONG
# 2 0.9848633 ARI36  LONG
# 3 0.5683484 ARI36  LONG
# [1] 1243   21

# %%
##filtering out samples having less than -750 days to conversion
A3_clr_v1<- A3_clr1 %>%
  filter(days_to_conversion >= -750)
A3_clr_v1%>%dim
# Out:
# [1] 1121   21

# %%
## removing the male samples to run the lm model
A3_clr_v2 <- A3_clr_v1 %>%
  filter(subject.biologicalSex != "Male")
A3_clr_v2%>%dim
# Out:
# [1] 950  21

# %%
A3_clr_v2
# Out:
#     sample.sampleKitGuid Status_Long.x X    BMI      days_to_conversion
# 1   KT00052              pre            3   24.65716 -714
# 2   KT00052              pre            1   24.65716 -714
# 3   KT00052              pre            4   24.65716 -714
# 4   KT00052              pre           13   24.65716 -714
# 5   KT00052              pre            2   24.65716 -714
# 6   KT00052              pre           17   24.65716 -714
# 7   KT00052              pre           15   24.65716 -714
# 8   KT00052              pre           12   24.65716 -714
# 9   KT00052              pre            9   24.65716 -714
# 10  KT00052              pre           18   24.65716 -714
# 11  KT00052              pre           14   24.65716 -714
# 12  KT00052              pre            6   24.65716 -714
# 13  KT00052              pre           10   24.65716 -714
# 14  KT00052              pre            7   24.65716 -714
# 15  KT00052              pre           11   24.65716 -714
# 16  KT00052              pre           19   24.65716 -714
# 17  KT00052              pre            8   24.65716 -714
# 18  KT00052              pre            5   24.65716 -714
# 19  KT00052              pre           16   24.65716 -714
# 20  KT00056              pre           48   25.94834 -632
# 21  KT00056              pre           42   25.94834 -632
# 22  KT00056              pre           46   25.94834 -632
# 23  KT00056              pre           51   25.94834 -632
# 24  KT00056              pre           41   25.94834 -632
# 25  KT00056              pre           54   25.94834 -632
# 26  KT00056              pre           40   25.94834 -632
# 27  KT00056              pre           52   25.94834 -632
# 28  KT00056              pre           53   25.94834 -632
# 29  KT00056              pre           45   25.94834 -632
# 30  KT00056              pre           44   25.94834 -632
# ⋮   ⋮                    ⋮             ⋮    ⋮        ⋮
# 921 KT04474              pre           2484 24.26808 -102
# 922 KT04474              pre           2471 24.26808 -102
# 923 KT04474              pre           2472 24.26808 -102
# 924 KT04474              pre           2473 24.26808 -102
# 925 KT04474              pre           2474 24.26808 -102
# 926 KT04474              pre           2475 24.26808 -102
# 927 KT04474              pre           2476 24.26808 -102
# 928 KT04474              pre           2477 24.26808 -102
# 929 KT04474              pre           2478 24.26808 -102
# 930 KT04474              pre           2481 24.26808 -102
# 931 KT04474              pre           2482 24.26808 -102
# 932 KT04924              conversion    2640 29.18762    0
# 933 KT04924              conversion    2641 29.18762    0
# 934 KT04924              conversion    2630 29.18762    0
# 935 KT04924              conversion    2631 29.18762    0
# 936 KT04924              conversion    2632 29.18762    0
# 937 KT04924              conversion    2633 29.18762    0
# 938 KT04924              conversion    2634 29.18762    0
# 939 KT04924              conversion    2635 29.18762    0
# 940 KT04924              conversion    2623 29.18762    0
# 941 KT04924              conversion    2624 29.18762    0
# 942 KT04924              conversion    2625 29.18762    0
# 943 KT04924              conversion    2626 29.18762    0
# 944 KT04924              conversion    2627 29.18762    0
# 945 KT04924              conversion    2628 29.18762    0
# 946 KT04924              conversion    2629 29.18762    0
# 947 KT04924              conversion    2638 29.18762    0
# 948 KT04924              conversion    2639 29.18762    0
# 949 KT04924              conversion    2636 29.18762    0
# 950 KT04924              conversion    2637 29.18762    0
#     ageAtDraw subject.biologicalSex subject.subjectGuid bmi_conv age_conv ⋯
# 1   56        Female                CU1009              25.64892 58       ⋯
# 2   56        Female                CU1009              25.64892 58       ⋯
# 3   56        Female                CU1009              25.64892 58       ⋯
# 4   56        Female                CU1009              25.64892 58       ⋯
# 5   56        Female                CU1009              25.64892 58       ⋯
# 6   56        Female                CU1009              25.64892 58       ⋯
# 7   56        Female                CU1009              25.64892 58       ⋯
# 8   56        Female                CU1009              25.64892 58       ⋯
# 9   56        Female                CU1009              25.64892 58       ⋯
# 10  56        Female                CU1009              25.64892 58       ⋯
# 11  56        Female                CU1009              25.64892 58       ⋯
# 12  56        Female                CU1009              25.64892 58       ⋯
# 13  56        Female                CU1009              25.64892 58       ⋯
# 14  56        Female                CU1009              25.64892 58       ⋯
# 15  56        Female                CU1009              25.64892 58       ⋯
# 16  56        Female                CU1009              25.64892 58       ⋯
# 17  56        Female                CU1009              25.64892 58       ⋯
# 18  56        Female                CU1009              25.64892 58       ⋯
# 19  56        Female                CU1009              25.64892 58       ⋯
# 20  42        Female                CU1007              26.19498 44       ⋯
# 21  42        Female                CU1007              26.19498 44       ⋯
# 22  42        Female                CU1007              26.19498 44       ⋯
# 23  42        Female                CU1007              26.19498 44       ⋯
# 24  42        Female                CU1007              26.19498 44       ⋯
# 25  42        Female                CU1007              26.19498 44       ⋯
# 26  42        Female                CU1007              26.19498 44       ⋯
# 27  42        Female                CU1007              26.19498 44       ⋯
# 28  42        Female                CU1007              26.19498 44       ⋯
# 29  42        Female                CU1007              26.19498 44       ⋯
# 30  42        Female                CU1007              26.19498 44       ⋯
# ⋮   ⋮         ⋮                     ⋮                   ⋮        ⋮        ⋱
# 921 61        Female                CU1010              24.55026 62       ⋯
# 922 61        Female                CU1010              24.55026 62       ⋯
# 923 61        Female                CU1010              24.55026 62       ⋯
# 924 61        Female                CU1010              24.55026 62       ⋯
# 925 61        Female                CU1010              24.55026 62       ⋯
# 926 61        Female                CU1010              24.55026 62       ⋯
# 927 61        Female                CU1010              24.55026 62       ⋯
# 928 61        Female                CU1010              24.55026 62       ⋯
# 929 61        Female                CU1010              24.55026 62       ⋯
# 930 61        Female                CU1010              24.55026 62       ⋯
# 931 61        Female                CU1010              24.55026 62       ⋯
# 932 35        Female                CU1052              29.18762 35       ⋯
# 933 35        Female                CU1052              29.18762 35       ⋯
# 934 35        Female                CU1052              29.18762 35       ⋯
# 935 35        Female                CU1052              29.18762 35       ⋯
# 936 35        Female                CU1052              29.18762 35       ⋯
# 937 35        Female                CU1052              29.18762 35       ⋯
# 938 35        Female                CU1052              29.18762 35       ⋯
# 939 35        Female                CU1052              29.18762 35       ⋯
# 940 35        Female                CU1052              29.18762 35       ⋯
# 941 35        Female                CU1052              29.18762 35       ⋯
# 942 35        Female                CU1052              29.18762 35       ⋯
# 943 35        Female                CU1052              29.18762 35       ⋯
# 944 35        Female                CU1052              29.18762 35       ⋯
# 945 35        Female                CU1052              29.18762 35       ⋯
# 946 35        Female                CU1052              29.18762 35       ⋯
# 947 35        Female                CU1052              29.18762 35       ⋯
# 948 35        Female                CU1052              29.18762 35       ⋯
# 949 35        Female                CU1052              29.18762 35       ⋯
# 950 35        Female                CU1052              29.18762 35       ⋯
#     Status_Xsec Age2023 anti_ccp3 anti_ccp3_finalCombined anti_ccp31 clusters
# 1   at_risk     60       88         88                     74        cluster2
# 2   at_risk     60       88         88                     74        cluster0
# 3   at_risk     60       88         88                     74        cluster3
# 4   at_risk     60       88         88                     74        cluster12
# 5   at_risk     60       88         88                     74        cluster1
# 6   at_risk     60       88         88                     74        cluster16
# 7   at_risk     60       88         88                     74        cluster14
# 8   at_risk     60       88         88                     74        cluster11
# 9   at_risk     60       88         88                     74        cluster8
# 10  at_risk     60       88         88                     74        cluster17
# 11  at_risk     60       88         88                     74        cluster13
# 12  at_risk     60       88         88                     74        cluster5
# 13  at_risk     60       88         88                     74        cluster9
# 14  at_risk     60       88         88                     74        cluster6
# 15  at_risk     60       88         88                     74        cluster10
# 16  at_risk     60       88         88                     74        cluster18
# 17  at_risk     60       88         88                     74        cluster7
# 18  at_risk     60       88         88                     74        cluster4
# 19  at_risk     60       88         88                     74        cluster15
# 20  at_risk     46      262       2544                    262        cluster9
# 21  at_risk     46      262       2544                    262        cluster3
# 22  at_risk     46      262       2544                    262        cluster7
# 23  at_risk     46      262       2544                    262        cluster12
# 24  at_risk     46      262       2544                    262        cluster2
# 25  at_risk     46      262       2544                    262        cluster15
# 26  at_risk     46      262       2544                    262        cluster1
# 27  at_risk     46      262       2544                    262        cluster13
# 28  at_risk     46      262       2544                    262        cluster14
# 29  at_risk     46      262       2544                    262        cluster6
# 30  at_risk     46      262       2544                    262        cluster5
# ⋮   ⋮           ⋮       ⋮         ⋮                       ⋮          ⋮
# 921 NA          62      302       302                     320        cluster7
# 922 NA          62      302       302                     320        cluster17
# 923 NA          62      302       302                     320        cluster14
# 924 NA          62      302       302                     320        cluster15
# 925 NA          62      302       302                     320        cluster16
# 926 NA          62      302       302                     320        cluster12
# 927 NA          62      302       302                     320        cluster13
# 928 NA          62      302       302                     320        cluster0
# 929 NA          62      302       302                     320        cluster1
# 930 NA          62      302       302                     320        cluster18
# 931 NA          62      302       302                     320        cluster5
# 932 early_RA    35      231       231                     226        cluster13
# 933 early_RA    35      231       231                     226        cluster17
# 934 early_RA    35      231       231                     226        cluster12
# 935 early_RA    35      231       231                     226        cluster0
# 936 early_RA    35      231       231                     226        cluster1
# 937 early_RA    35      231       231                     226        cluster14
# 938 early_RA    35      231       231                     226        cluster3
# 939 early_RA    35      231       231                     226        cluster4
# 940 early_RA    35      231       231                     226        cluster7
# 941 early_RA    35      231       231                     226        cluster11
# 942 early_RA    35      231       231                     226        cluster8
# 943 early_RA    35      231       231                     226        cluster9
# 944 early_RA    35      231       231                     226        cluster10
# 945 early_RA    35      231       231                     226        cluster6
# 946 early_RA    35      231       231                     226        cluster2
# 947 early_RA    35      231       231                     226        cluster15
# 948 early_RA    35      231       231                     226        cluster16
# 949 early_RA    35      231       231                     226        cluster5
# 950 early_RA    35      231       231                     226        cluster18
#     frequency_live clr          s1_ids Status_new
# 1   0.096219931     0.90482062  ARI36  LONG
# 2   0.104238259     0.98486333  ARI36  LONG
# 3   0.068728522     0.56834839  ARI36  LONG
# 4   0.046964490     0.18757589  ARI36  LONG
# 5   0.070733104     0.59709780  ARI36  LONG
# 6   0.022909507    -0.53026390  ARI36  LONG
# 7   0.029495991    -0.27756155  ARI36  LONG
# 8   0.029782360    -0.26789964  ARI36  LONG
# 9   0.063860252     0.49488123  ARI36  LONG
# 10  0.016609393    -0.85184753  ARI36  LONG
# 11  0.005727377    -1.91655826  ARI36  LONG
# 12  0.097651775     0.91959194  ARI36  LONG
# 13  0.053550974     0.31881808  ARI36  LONG
# 14  0.072737686     0.62504373  ARI36  LONG
# 15  0.063860252     0.49488123  ARI36  LONG
# 16  0.002290951    -2.83284900  ARI36  LONG
# 17  0.051260023     0.27509527  ARI36  LONG
# 18  0.076460481     0.67495812  ARI36  LONG
# 19  0.026918671    -0.36899576  ARI36  LONG
# 20  0.063520871     0.47184784  ARI46  LONG
# 21  0.063520871     0.47184784  ARI46  LONG
# 22  0.036902601    -0.07123864  ARI46  LONG
# 23  0.029643073    -0.29029221  ARI46  LONG
# 24  0.123714459     1.13845547  ARI46  LONG
# 25  0.029038113    -0.31091150  ARI46  LONG
# 26  0.047791894     0.18733535  ARI46  LONG
# 27  0.002722323    -2.67803511  ARI46  LONG
# 28  0.037810042    -0.04694595  ARI46  LONG
# 29  0.077434967     0.66991776  ARI46  LONG
# 30  0.065638234     0.50463767  ARI46  LONG
# ⋮   ⋮              ⋮            ⋮      ⋮
# 921 0.0523289247    0.377659364 ARI41  LONG
# 922 0.0123634273   -1.065147207 ARI41  LONG
# 923 0.0439907993    0.204090599 ARI41  LONG
# 924 0.0359401955    0.001966415 ARI41  LONG
# 925 0.0132259919   -0.997705926 ARI41  LONG
# 926 0.0385278896    0.071492477 ARI41  LONG
# 927 0.0020126509   -2.880437174 ARI41  LONG
# 928 0.0713053479    0.687081424 ARI41  LONG
# 929 0.1003450259    1.028724600 ARI41  LONG
# 930 0.0017251294   -3.034587853 ARI41  LONG
# 931 0.0980448534    1.005535155 ARI41  LONG
# 932 0.0041745731   -2.109295058 ARI45  LONG
# 933 0.0056925996   -1.799140130 ARI45  LONG
# 934 0.0413662239    0.184157551 ARI45  LONG
# 935 0.1051233397    1.116827175 ARI45  LONG
# 936 0.0743833017    0.770924328 ARI45  LONG
# 937 0.0375711575    0.087929519 ARI45  LONG
# 938 0.0918406072    0.981747395 ARI45  LONG
# 939 0.0804554080    0.849395944 ARI45  LONG
# 940 0.0557874763    0.483242256 ARI45  LONG
# 941 0.0246679317   -0.332803061 ARI45  LONG
# 942 0.0603415560    0.561713871 ARI45  LONG
# 943 0.0584440228    0.529762272 ARI45  LONG
# 944 0.0648956357    0.634473226 ARI45  LONG
# 945 0.0660341556    0.651864968 ARI45  LONG
# 946 0.0736242884    0.760667828 ARI45  LONG
# 947 0.0451612903    0.271933162 ARI45  LONG
# 948 0.0148007590   -0.843628685 ARI45  LONG
# 949 0.0948766603    1.014270587 ARI45  LONG
# 950 0.0007590133   -3.814043150 ARI45  LONG

# %%
A3_clr_v2%>%colnames%>%sort
# Out:
#  [1] "Age2023"                 "BMI"
#  [3] "Status_Long.x"           "Status_Long.y"
#  [5] "Status_Xsec"             "Status_new"
#  [7] "X"                       "ageAtDraw"
#  [9] "age_conv"                "anti_ccp3"
# [11] "anti_ccp31"              "anti_ccp3_finalCombined"
# [13] "bmi_conv"                "clr"
# [15] "clusters"                "days_to_conversion"
# [17] "frequency_live"          "s1_ids"
# [19] "sample.sampleKitGuid"    "subject.biologicalSex"
# [21] "subject.subjectGuid"

# %%
# cluster 3
  cluster_data <- A3_clr_v2 %>% filter(clusters == "cluster3")
  
  # Fit the linear mixed-effects model
  model_C3 <- lmerTest::lmer(frequency_live ~ age_conv + bmi_conv + days_to_conversion + (1 | subject.subjectGuid), data = cluster_data)

# %%
cluster_data%>%dim
# Out:
# [1] 50 21

# %%
summary(model_C3)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: frequency_live ~ age_conv + bmi_conv + days_to_conversion + (1 |
#     subject.subjectGuid)
#    Data: cluster_data
#
# REML criterion at convergence: -177.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2055 -0.6176 -0.1725  0.6808  2.7635
#
# Random effects:
#  Groups              Name        Variance  Std.Dev.
#  subject.subjectGuid (Intercept) 7.309e-05 0.008549
#  Residual                        5.278e-04 0.022974
# Number of obs: 50, groups:  subject.subjectGuid, 13
#
# Fixed effects:
#                      Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)         1.001e-01  2.290e-02  6.675e+00   4.372  0.00366 **
# age_conv           -4.143e-04  3.126e-04  6.764e+00  -1.325  0.22805
# bmi_conv            3.419e-04  7.382e-04  6.534e+00   0.463  0.65831
# days_to_conversion  4.973e-05  1.531e-05  4.600e+01   3.249  0.00217 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ag_cnv bm_cnv
# age_conv    -0.415
# bmi_conv    -0.747 -0.241
# dys_t_cnvrs  0.127 -0.004  0.070

# %%
PlotFreqLinePlot1(cluster_data %>% mutate(Sex=subject.biologicalSex), model_fit=model_C3, palette=cluster_colors,
                 fig_path = fig_path,fig_name ="Fig_Mem_CD4T_Cluster3_frequency.pdf",
                  x_var = "days_to_conversion", y_var = "frequency_live", color_var = "subject.subjectGuid",
                  shape_var = "Sex", title = "Cluster 3", x_label = "Days to Conversion", 
                  y_label = "Frequency", 
                 #annotation_text = "padj=0.030",
                  annotation_x = -600, 
                  annotation_y =1.7, annotation_color = "black")
# Out:
# Loading required package: ggeffects
#
# Warning message:
# “package ‘ggeffects’ was built under R version 4.3.3”
#
# Attaching package: ‘ggeffects’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_title
#
#
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/workspace/environment/r_scrna/lib/libopenblasp-r0.3.24.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=C.UTF-8    LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: America/Los_Angeles
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] ggeffects_1.7.0             cowplot_1.1.1
#  [3] GSVA_1.48.2                 ggthemes_5.1.0
#  [5] ggrepel_0.9.3               lme4_1.1-34
#  [7] plotly_4.10.2               knitr_1.44
#  [9] SingleCellExperiment_1.22.0 SummarizedExperiment_1.30.2
# [11] Biobase_2.60.0              GenomicRanges_1.52.0
# [13] GenomeInfoDb_1.36.1         IRanges_2.34.1
# [15] S4Vectors_0.38.1            BiocGenerics_0.46.0
# [17] MatrixGenerics_1.12.2       matrixStats_1.0.0
# [19] future.apply_1.11.0         future_1.33.0
# [21] viridis_0.6.4               viridisLite_0.4.2
# [23] Matrix_1.6-1.1              SeuratObject_4.1.4
# [25] Seurat_4.4.0                lubridate_1.9.3
# [27] forcats_1.0.0               stringr_1.5.0
# [29] dplyr_1.1.3                 purrr_1.0.2
# [31] readr_2.1.4                 tidyr_1.3.0
# [33] tibble_3.2.1                ggplot2_3.4.3
# [35] tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.21          splines_4.3.1
#   [3] later_1.3.1               pbdZMQ_0.3-10
#   [5] bitops_1.0-7              datawizard_0.11.0
#   [7] polyclip_1.10-6           graph_1.78.0
#   [9] XML_3.99-0.14             lifecycle_1.0.3
#  [11] globals_0.16.2            lattice_0.21-9
#  [13] MASS_7.3-60               insight_0.20.1
#  [15] magrittr_2.0.3            httpuv_1.6.11
#  [17] sctransform_0.4.0         sp_2.1-0
#  [19] spatstat.sparse_3.0-2     reticulate_1.32.0
#  [21] pbapply_1.7-2             DBI_1.1.3
#  [23] minqa_1.2.6               RColorBrewer_1.1-3
#  [25] abind_1.4-5               zlibbioc_1.46.0
#  [27] Rtsne_0.16                RCurl_1.98-1.12
#  [29] GenomeInfoDbData_1.2.10   irlba_2.3.5.1
#  [31] listenv_0.9.0             spatstat.utils_3.0-3
#  [33] goftest_1.2-3             spatstat.random_3.1-6
#  [35] annotate_1.78.0           fitdistrplus_1.1-11
#  [37] parallelly_1.36.0         DelayedMatrixStats_1.22.1
#  [39] leiden_0.4.3              codetools_0.2-19
#  [41] DelayedArray_0.26.6       tidyselect_1.2.0
#  [43] farver_2.1.1              ScaledMatrix_1.8.1
#  [45] base64enc_0.1-3           spatstat.explore_3.2-3
#  [47] jsonlite_1.8.7            ellipsis_0.3.2
#  [49] progressr_0.14.0          ggridges_0.5.4
#  [51] survival_3.5-7            systemfonts_1.0.5
#  [53] tools_4.3.1               ragg_1.2.5
#  [55] ica_1.0-3                 Rcpp_1.0.11
#  [57] glue_1.7.0                gridExtra_2.3
#  [59] xfun_0.40                 IRdisplay_1.1
#  [61] HDF5Array_1.28.1          numDeriv_2016.8-1.1
#  [63] withr_2.5.1               fastmap_1.1.1
#  [65] rhdf5filters_1.12.1       boot_1.3-28.1
#  [67] fansi_1.0.5               rsvd_1.0.5
#  [69] digest_0.6.33             timechange_0.2.0
#  [71] R6_2.5.1                  mime_0.12
#  [73] textshaping_0.3.7         colorspace_2.1-0
#  [75] scattermore_1.2           tensor_1.5
#  [77] spatstat.data_3.0-1       RSQLite_2.3.1
#  [79] utf8_1.2.3                generics_0.1.3
#  [81] data.table_1.14.8         httr_1.4.7
#  [83] htmlwidgets_1.6.2         S4Arrays_1.0.4
#  [85] uwot_0.1.16               pkgconfig_2.0.3
#  [87] gtable_0.3.4              blob_1.2.4
#  [89] lmtest_0.9-40             XVector_0.40.0
#  [91] htmltools_0.5.6.1         GSEABase_1.62.0
#  [93] scales_1.2.1              png_0.1-8
#  [95] tzdb_0.4.0                reshape2_1.4.4
#  [97] uuid_1.1-1                nlme_3.1-163
#  [99] nloptr_2.0.3              rhdf5_2.44.0
# [101] repr_1.1.6                zoo_1.8-12
# [103] cachem_1.0.8              sjlabelled_1.2.0
# [105] KernSmooth_2.23-22        parallel_4.3.1
# [107] miniUI_0.1.1.1            AnnotationDbi_1.62.2
# [109] pillar_1.9.0              grid_4.3.1
# [111] vctrs_0.6.3               RANN_2.6.1
# [113] promises_1.2.1            BiocSingular_1.16.0
# [115] beachmat_2.16.0           xtable_1.8-4
# [117] cluster_2.1.4             evaluate_0.22
# [119] cli_3.6.1                 compiler_4.3.1
# [121] rlang_1.1.1               crayon_1.5.2
# [123] labeling_0.4.3            plyr_1.8.9
# [125] stringi_1.7.12            BiocParallel_1.34.2
# [127] deldir_1.0-9              lmerTest_3.1-3
# [129] Biostrings_2.68.1         munsell_0.5.0
# [131] lazyeval_0.2.2            spatstat.geom_3.2-5
# [133] IRkernel_1.3.2            hms_1.1.3
# [135] patchwork_1.1.3           sparseMatrixStats_1.12.2
# [137] bit64_4.0.5               Rhdf5lib_1.22.0
# [139] KEGGREST_1.40.0           shiny_1.7.5
# [141] haven_2.5.3               ROCR_1.0-11
# [143] igraph_1.5.1              memoise_2.0.1
# [145] bit_4.0.5
