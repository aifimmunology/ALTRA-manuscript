# %%
import sys
import getopt
import matplotlib.pyplot as plt
import shutil
import h5py
import re
import os
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
import scrublet
from multiprocessing import Pool

# %%
h5_list = ['h5_input/EXP-00723-P1_SP00257-01-1.h5','h5_input/EXP-00723-P1_SP00257-01-2.h5',
           'h5_input/EXP-00723-P1_SP00287-02-1.h5','h5_input/EXP-00723-P1_SP00287-02-2.h5',
           'h5_input/EXP-00723-P1_SP01565-01-1.h5','h5_input/EXP-00723-P1_SP01565-01-2.h5',
           'h5_input/EXP-00723-P1_SP01606-01-1.h5','h5_input/EXP-00723-P1_SP01606-01-2.h5']

# %%
for h5_in in h5_list:
    print(h5_in)

    # Perform Scrublet & celltypist
    adata = sc.read_10x_h5(h5_in)
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    predictions_l1 = celltypist.annotate(adata, model='ref_pbmc_clean_celltypist_model_AIFI_L1_2024-04-18.pkl')
    df1 = predictions_l1.predicted_labels
    predictions_l2 = celltypist.annotate(adata, model='ref_pbmc_clean_celltypist_model_AIFI_L2_2024-04-19.pkl')
    df2 = predictions_l2.predicted_labels
    predictions_l3 = celltypist.annotate(adata, model='ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl')
    df3 = predictions_l3.predicted_labels
    adata.shape
    scrub = scrublet.Scrublet(adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose = False)
    
    # Add Scrublet information to h5 file
    h5_con = h5py.File(h5_in, 'r+')
    h5_con['matrix']['observations']['AIFI_PBMC_L1'] = df1['predicted_labels'].tolist()
    h5_con['matrix']['observations']['AIFI_PBMC_L2'] = df2['predicted_labels'].tolist()
    h5_con['matrix']['observations']['AIFI_PBMC_L3'] = df3['predicted_labels'].tolist()
    h5_con['matrix']['observations']['scrublet_score'] = doublet_scores
    h5_con['matrix']['observations']['scrublet_call'] = predicted_doublets.astype(int)
    h5_con.close()
# Out:
# h5_input/EXP-00723-P1_SP00257-01-1.h5
# 🔬 Input data has 21732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 21732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 21732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP00257-01-2.h5
# 🔬 Input data has 21494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 21494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 21494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP00287-02-1.h5
# 🔬 Input data has 17769 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17769 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17769 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP00287-02-2.h5
# 🔬 Input data has 16564 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16564 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16564 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP01565-01-1.h5
# 🔬 Input data has 17647 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17647 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17647 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP01565-01-2.h5
# 🔬 Input data has 16630 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16630 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16630 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP01606-01-1.h5
# 🔬 Input data has 19637 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 19637 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 19637 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# h5_input/EXP-00723-P1_SP01606-01-2.h5
# 🔬 Input data has 16237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
